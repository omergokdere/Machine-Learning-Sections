# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Natural Language Processing Project
#
# Welcome to the NLP Project for this section of the course. In this NLP project you will be attempting to classify Yelp Reviews into 1 star or 5 star categories based off the text content in the reviews. This will be a simpler procedure than the lecture, since we will utilize the pipeline methods for more complex tasks.
#
# We will use the [Yelp Review Data Set from Kaggle](https://www.kaggle.com/c/yelp-recsys-2013).
#
# Each observation in this dataset is a review of a particular business by a particular user.
#
# The "stars" column is the number of stars (1 through 5) assigned by the reviewer to the business. (Higher stars is better.) In other words, it is the rating of the business by the person who wrote the review.
#
# The "cool" column is the number of "cool" votes this review received from other Yelp users.
#
# All reviews start with 0 "cool" votes, and there is no limit to how many "cool" votes a review can receive. In other words, it is a rating of the review itself, not a rating of the business.
#
# The "useful" and "funny" columns are similar to the "cool" column.
#
# Let's get started! Just follow the directions below!

# %% [markdown]
# ## Imports
#  **Import the usual suspects. :) **

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## The Data
#
# **Read the yelp.csv file and set it as a dataframe called yelp.**

# %%
yelp = pd.read_csv('/Users/Faheem/Desktop/yelp.csv', encoding="utf8")

# %% [markdown]
# ** Check the head, info , and describe methods on yelp.**

# %%
yelp[yelp.review_text.str.contains("pizza") == True]
# Out:
#                     business_id  stars  \
# 0        iCQpiavjjPzJ5_3gPD5Ebg      2
# 94       amsvLzfEvCzLwP0MnXAJ1w      4
# 122      b8HHE-JcnkXyS0Wjp50wFw      5
# 167      NFaVXGofY855SyGs6D3_-Q      5
# 198      SbWqeztXrCTsYMsf6KGYvg      5
# 229      DZfFFSVFVJVxs3vfFVVf0w      3
# 239      _7FdoBvlZH64Zx52ISc59Q      4
# 260      LXheNwqZPoXuXNNeP1sNew      4
# 272      W36vefYka0IZAPWygxJtqg      5
# 290      ANAGlfG4ELW3jiO62GQ1zw      2
# 307      ZZbaD-DKkILA_FvliElciw      2
# 308      64o_nYvzIKwHFOSYSEm-qw      5
# 322      szeG61Jn4dFrLqhZy0m_ug      5
# 350      JFNv5sKeKAf1ZVPnfbzpXw      5
# 357      7tNY4BYLA4laqWNV4IWGQg      4
# 370      8xrwjD-Udv7cm_emVcVo3A      5
# 374      pjpUOlJLlkIxBZ5BquA2PA      5
# 377      Y1-nbySEHec051ix7beSGw      3
# 380      EHmxhhpj2kwYhCgKdRXmqw      4
# 381      pxv5jBUOgsg6Rf6Z88e4mg      5
# 407      4UevPCjXBdlMoC8Ns5sRxQ      5
# 409      qpfCMda5NPEL-CBh1Vhw1Q      1
# 426      4IXTkqYmAO4XH4nXnwc67w      4
# 438      F8xyyUMEU7s98zLhviR5gg      4
# 442      sZkmUH_oRUhCgb4uhoS-zQ      5
# 448      lwxYmWqjmEZ0ukCsXC9Pfg      5
# 464      nzbQXU2x7O8oucKGthUT3g      5
# 465      5ykOWYZ44sUvu9qxD8rPeg      5
# 466      F1PMcEIg-FHZvwhiUoFEgw      3
# 495      pSQFynH1VxkfSmehRXlZWw      5
# ...                         ...    ...
# 3657590  FMnH5WIRLyexBYMBUUnDxQ      4
# 3657662  Sm2k1ijcnK17Ro5paN2_qQ      3
# 3657680  bgXb5YYzQvHXmM8owZB4fQ      4
# 3657702  znWHLW1pt19HzW1VY6KfCA      3
# 3657732  R073RHVTWuUc_JabjD0bsA      5
# 3657735  Mh84_j7YmRrAcm0DWV4bUw      5
# 3657750  amMyPg5Pm7OvplWqvwhvVg      1
# 3657764  W1vydY_gBcNQVsOGlkdtDA      5
# 3657786  iCQpiavjjPzJ5_3gPD5Ebg      4
# 3657827  Ei21gZXbsXbJlWL0QxLVzA      1
# 3657845  5keoVVM81g-nJw0Zdpl1nA      5
# 3657862  uE6hI5_i4QVq12xU99xtqA      1
# 3657864  0rjU_WK5HxoH1fIuEpTpcg      5
# 3657867  fBtBizbJDlcXfAOb8GmFsg      1
# 3657877  iCQpiavjjPzJ5_3gPD5Ebg      5
# 3657891  2wCzZUwcqRRBrAtBBYxnog      5
# 3657902  kafUXRNfQm3e_U14S2WbmA      5
# 3657919  6We2O5X62J_gduXU7jvf8w      4
# 3657920  UdEmYOnk2iJDY9lpEPAlJQ      5
# 3657922  vX5ma5Nwrzqwdz949AmVVg      3
# 3657934  uLL2uKqYnPAFwBw11LzDUQ      1
# 3657950  VjaHHmV-rSkFaOAnU3faxg      5
# 3657952  QfG4JZvFoFpRbAxU2Fn-UQ      1
# 3657961  ecM2lSLuZhxZKQdGZWMOFg      3
# 3657966  ZliwQrjUnAosBLM8W_bsGQ      5
# 3657968  LDxapKCuUbH-G24O4vjD7g      4
# 3657986  O-GefJqucTHDIYJSxVhEyA      4
# 3657989  yPgUkQxj8CYPKF89HV65kg      4
# 3657990  GnODIDJz09LecpudDoynCg      4
# 3657993  Xc3Y8_cWBnMVXvoJmGCh4g      2
#
#                                                review_text  is_useful  \
# 0        The pizza was okay. Not the best I've had. I p...          0
# 94       Since it opened, this place has become a West ...          1
# 122      Amazing pizza place. \nThe ladies and gentleme...          0
# 167      Their pizzas were so go, I had to order a seco...          0
# 198      I always got good food here. Maybe not the bes...          0
# 229      I suppose if you're form the East Coast, this ...          1
# 239      I am from Chicago, and was very impressed with...          1
# 260      Really another very good lunch! Tried the pizz...          1
# 272      Well, you guys did it now!!!! \n\nMy parents c...          1
# 290      We stayed at the Wynn and ended up at this res...          0
# 307      This location is terribly ran and managed. You...          0
# 308      Tried the humongous white spinach pizza and ad...          0
# 322      Every day on my way to work, I drive past this...          0
# 350      This place deserves another try from last cust...          1
# 357      Love Love Love this place I bring all My frien...          0
# 370      This is my favorite pizza! I tried a bunch of ...          0
# 374      This place is absolutely amazing.  Went with f...          1
# 377      Your place has so much potential ....it looks ...          1
# 380      Love this place for a quick lunch.   \nLately ...          0
# 381      Great atmosphere and friendly staff.  Thursday...          0
# 407      Awesome pizza! Super yummy!  Best thin crust e...          0
# 409      Honestly, this place is TERRIBLE. I used to lo...          1
# 426      This place was great for a casual get-together...          1
# 438      This pizza is good!!\nI used Uber Eats to orde...          0
# 442      Love this place.  The Pizza is amazing.  Love ...          0
# 448      My most recent visit to Giordano's Las Vegas (...          1
# 464      Best pizza in the valley!  The main dining roo...          0
# 465      Very solid pizza with great atmosphere!  Low k...          0
# 466      I am a huge fan of Grimaldi's pizza and when t...          0
# 14       q0n4I-zqiI47xispOqc1lA      5
# 15       gZGsReG0VeX4uKViHTB9EQ      5
# 16       -bd4BQcl1ekgo7avaFngIw      5
# 17       u73j2VQ3TGWdMO-AG7MABw      2
# 18       VyVIneSU7XAWgMBllI6LnQ      5
# 19       jqAdZf9PJo8lsRskc6T1Sw      4
# 20       f-v1fvtnbdw_QQRsCnwH-g      1
# 21       yz66FIUPDKGhILDWzRLeKg      1
# 22       6qDRqHWqf0EeHupSUEBfKg      5
# 23       7AlULGZI1pHt0imODsqdkg      5
# 24       th4pZ5LkoIIkb1Vmu_m2DA      4
# 25       nsSfCKW9KDB4COj9bzXApw      5
# 26       Edr6SafmQrZa6CcFuItoqg      2
# 27       NASjUYKkz6l7hQLxMf2lqg      5
# 28       w5CSi-An5meLnxjKSFn0wQ      5
# 29       RyTEGJz5tG7zC73BdXt-cQ      5
# ...                         ...    ...
# 3657988  eJYvivWUp4Hdc9Tc8SaZPA      4
# 3657989  yPgUkQxj8CYPKF89HV65kg      4
# 3657990  GnODIDJz09LecpudDoynCg      4
# 3657991  QlAPX3c0Vm2dU_w3puIAIw      5
# 3657992  uqnFLc-1MxWw5f4SIyEf4Q      5
# 3657993  Xc3Y8_cWBnMVXvoJmGCh4g      2
# 3657994  t67GMPZ0cv_ItKlID-JFiQ      5
# 3657995  Trs4cEYdP6AX_KihTk9kWQ      4
# 3657996  gRMYm-CeEdjXtaQcVo8vsw      1
# 3657997  WbS58nfQQZaxWk1BUPBuJQ      4
# 3657998  G099MT9cwtwgdsR71JLp6w      5
# 3657999  wsmVIHJEi9J_38dXx2qLKA      3
# 3658000  j1i7s55PmOFzJC3l6O8PiA      4
# 3658001  zjwdU1OdlbKTGjm-IfD4TQ      3
# 3658002  ceuvH6NpDhpT1p4q1w93pA      4
# 3658003  HHCn1akqIpl_BhdcJoYPbw      4
# 3658004  vzqzoa-plufwTsQUwW_s6Q      4
# 3658005  3-HFGxmbzSax-NySJ_LzDg      5
# 3658006  oglIZt5mg2nErhpTH_AakQ      4
# 3658007  OPSNdO3LNPMt7qz1MNb42g      5
# 3658008  JcMx_PIy0ROIlJWens4TAQ      5
# 3658009  XF7cEaCGuPkt1yuz77jeTQ      5
# 3658010  aLcFhMe6DDJ430zelCpd2A      4
# 3658011  R_fQGSUQv0L_fRiuua47dw      5
# 3658012  BdzJQypceJ5Bam2P7egoiw      4
# 3658013  zr42_UsWfaIF-rcp37OpwA      5
# 3658014  abIF7pw1Hyu-eVW3LwNhyg      1
# 3658015  fbLYRHIZAt3q839whhaBUg      1
# 3658016  b_8jCti0vuouJ_fjZpdmZw      4
# 3658017  wY3dlpLa0BHfDENYAPYuZA      1
#
#                                                review_text  is_useful  \
# 0        The pizza was okay. Not the best I've had. I p...          0
# 1        Terrible. Dry corn bread. Rib tips were all fa...          1
# 2        Back in 2005-2007 this place was my FAVORITE t...          1
# 3        Delicious healthy food. The steak is amazing. ...          0
# 4        If you like Thai food, you have to try the ori...          1
# 5        I'm not a burger-fries-shake kind of person, h...          0
# 6        One of my favorite hang-out spots in Vegas!  M...          1
# 7        AMAZING!!!\n\n I was referred here by a friend...          0
# 8        Ribs = amazing\n2 hour wait time= not so amazi...          0
# 9        Food is pretty good, not gonna lie. BUT you ha...          1
# 10       The score should be negative. Its HORRIBLE. Th...          0
# 11       Sansotei serves some top notch ramen. They tak...          0
# 12       Of the several places to get bagels in Oakland...          0
# 13       Cool little place, nice atmosphere and staff. ...          0
# 14       Delicious, friendly staff, cool atmosphere, al...          0
# 15       Finally! After trying many Mexican restaurants...          0
# 16       One of the best breakfast places I've been to!...          0
# 17       Food was alright, the service was HORRIBLE! Bo...          1
# 18       DELICIOUS! forgot to take a before picture but...          0
# 19       Large restaurant close to Old Town and Arts Di...          0
# 20       I have to write a review on the Fractured Prun...          0
# 21       I wish i could tell you all about the food but...          1
# 22       Wonderful! One of my favorite places. BBQ is e...          0
# 23       The price is about the same as Quizinos. The s...          0
# 24       The food was ok. You get a lot of food for the...          0
# 25       The staff were friendly and helpful. The food ...          1
# 26       Limited vegetarian options. Ordered Greek sala...          0
# 27       A tiny place with amazing food!! Flew in from ...          0
# 28       Food was very tasty and just enough spice.  De...          0
# 29       Best veal sandwich ever ( i like rapini/ garli...          0
# ...                                                    ...        ...
# 3657988  Search for Ethiopian Restaurants on Madison Ye...          1
# 3657989  Not much to add. An older established Italian ...          1
# 3657990  The place is small with a low ceiling. It's in...          1
# 3657991  To a devout Pastafarian, noodle soups are a co...          1
# 3657992  So... Wine and beer is now available. It's lim...          1
# 3657993  Looking for inexpensive pie with salad from a ...          1
# 3657994  They've got the best falafel I've ever eaten. ...          1
# 3657995  A solid Turkish place. They cover all the basi...          0
# 3657996  Service here was terrible. We are a party of 1...          0
# 3657997  Delicious food with many healthy options to ch...          0
# 3657998  Clearly one of the best in town. Corey D. thin...          1
# 3657999  Decent Eastside spot serving both Mediterranea...          1
# 3658000  They have their new sign up so don't say you c...          1
# 3658001  Do you have any local beers? \nNo, we're not a...          1
# 3658002  New to the neighborhood and working my way dow...          0
# 3658003  Time for an update.\n\nI've warmed to this pla...          1
# 3658004  PNNH makes the grade. I've been here twice and...          1
# 3658005  The S.U. was out of town, it was cold and rath...          1
# 3658006  The S.U. and I were on our way home from the a...          1
# 3658007  Food was delicious. Loved the service of Eric!...          0
# 3658008  I absolutely recommend this place. Me and my h...          1
# 3658009  A few years back I visited the location on Law...          0
# 3658010  On the plus side: Excellent Thai food, good fl...          0
# 3658011  I brought my coworkers and boss here for a lig...          1
# 3658012  Good food for moderate prices. I had a custom ...          1
# 3658013  Food: Amazing. I had the Smoked Salmon Benedic...          0
# 3658014  I must admit i have had very bad experience he...          0
# 3658015  Worst service experience in awhile. I usually ...          0
# 3658016  Loved the location, the patio, the service, an...          0
# 3658017  I absolutely hate this place. I would give it ...          0
#
#          is_funny  is_cool  positive_review_counter_business   longitude  \
# 0               0        0                               NaN -115.174212
# 1               1        1                               NaN -115.234495
# 2               0        0                               NaN -115.241323
# 3               0        0                               NaN -115.287045
# 4               0        0                               NaN -115.151632
# 5               0        0                               NaN -115.331454
# 6               1        1                               NaN -115.154480
# %%
yelp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3658018 entries, 0 to 3658017
# Data columns (total 9 columns):
# business_id                         object
# stars                               int64
# review_text                         object
# is_useful                           int64
# is_funny                            int64
# is_cool                             int64
# positive_review_counter_business    float64
# longitude                           float64
# latitude                            float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 251.2+ MB

# %%
yelp.describe()
# Out:
#               stars     is_useful      is_funny       is_cool  \
# count  3.658018e+06  3.658018e+06  3.658018e+06  3.658018e+06
# mean   3.714371e+00  4.357070e-01  2.005140e-01  2.521196e-01
# std    1.365544e+00  4.958492e-01  4.003851e-01  4.342296e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    4.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    5.000000e+00  1.000000e+00  0.000000e+00  1.000000e+00
# max    5.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#        positive_review_counter_business     longitude      latitude
# count                               0.0  3.658018e+06  3.658018e+06
# mean                                NaN -1.011584e+02  3.760410e+01
# std                                 NaN  1.661338e+01  4.312740e+00
# min                                 NaN -1.235874e+02 -7.175394e+01
# 25%                                 NaN -1.151481e+02  3.363558e+01
# 50%                                 NaN -1.119315e+02  3.611360e+01
# 75%                                 NaN -8.082795e+01  4.142212e+01
# max                                 NaN  1.150868e+02  5.943818e+01

# %% [markdown]
# **Create a new column called "text length" which is the number of words in the text column.**

# %%
yelp['length'] = yelp['review_text'].apply(len)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-7bc17135ed10> in <module>()
# ----> 1 yelp['length'] = yelp['review_text'].apply(len)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3190             else:
#    3191                 values = self.astype(object).values
# -> 3192                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3193
#    3194         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# TypeError: object of type 'float' has no len()

# %% [markdown]
# # EDA
#
# Let's explore the data
#
# ## Imports
#
# **Import the data visualization libraries if you haven't done so already.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
# %matplotlib inline

# %% [markdown]
# **Use FacetGrid from the seaborn library to create a grid of 5 histograms of text length based off of the star ratings. Reference the seaborn documentation for hints on this**

# %%
g = sns.FacetGrid(yelp,col='stars')
g.map(plt.hist,'text length')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-5a43ffd17154> in <module>()
#       1 g = sns.FacetGrid(yelp,col='stars')
# ----> 2 g.map(plt.hist,'text length')
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     730
#     731             # Get the actual data we are going to plot with
# --> 732             plot_data = data_ijk[list(args)]
#     733             if self._dropna:
#     734                 plot_data = plot_data.dropna()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['text length'] not in index"

# %% [markdown]
# **Create a boxplot of text length for each star category.**

# %%
sns.boxplot(x='stars',y='text length',data=yelp,palette='rainbow')

# %% [markdown]
# **Create a countplot of the number of occurrences for each type of star rating.**

# %%
sns.countplot(x='stars',data=yelp,palette='rainbow')

# %% [markdown]
# ** Use groupby to get the mean values of the numerical columns, you should be able to create this dataframe with the operation:**

# %%
stars = yelp.groupby('stars').mean()
stars
# Out:
#            cool    useful     funny  text length
# stars
# 1      0.576769  1.604806  1.056075   826.515354
# 2      0.719525  1.563107  0.875944   842.256742
# 3      0.788501  1.306639  0.694730   758.498289
# 4      0.954623  1.395916  0.670448   712.923142
# 5      0.944261  1.381780  0.608631   624.999101

# %% [markdown]
# **Use the corr() method on that groupby dataframe to produce this dataframe:**

# %%
stars.corr()
# Out:
#                  cool    useful     funny  text length
# cool         1.000000 -0.743329 -0.944939    -0.857664
# useful      -0.743329  1.000000  0.894506     0.699881
# funny       -0.944939  0.894506  1.000000     0.843461
# text length -0.857664  0.699881  0.843461     1.000000

# %% [markdown]
# **Then use seaborn to create a heatmap based off that .corr() dataframe:**

# %%
sns.heatmap(stars.corr(),cmap='coolwarm',annot=True)

# %% [markdown]
# ## NLP Classification Task
#
# Let's move on to the actual task. To make things a little easier, go ahead and only grab reviews that were either 1 star or 5 stars.
#
# **Create a dataframe called yelp_class that contains the columns of yelp dataframe but for only the 1 or 5 star reviews.**

# %%
yelp_class = yelp[(yelp.stars==1) | (yelp.stars==5)]

# %% [markdown]
# ** Create two objects X and y. X will be the 'text' column of yelp_class and y will be the 'stars' column of yelp_class. (Your features and target/labels)**

# %%
X = yelp_class['text']
y = yelp_class['stars']

# %% [markdown]
# **Import CountVectorizer and create a CountVectorizer object.**

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()

# %% [markdown]
# ** Use the fit_transform method on the CountVectorizer object and pass in X (the 'text' column). Save this result by overwriting X.**

# %%
X = cv.fit_transform(X)

# %% [markdown]
# ## Train Test Split
#
# Let's split our data into training and testing data.
#
# ** Use train_test_split to split up the data into X_train, X_test, y_train, y_test. Use test_size=0.3 and random_state=101 **

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3,random_state=101)

# %% [markdown]
# ## Training a Model
#
# Time to train a model!
#
# ** Import MultinomialNB and create an instance of the estimator and call is nb **

# %%
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()

# %% [markdown]
# **Now fit nb using the training data.**

# %%
nb.fit(X_train,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# ## Predictions and Evaluations
#
# Time to see how our model did!
#
# **Use the predict method off of nb to predict labels from X_test.**

# %%
predictions = nb.predict(X_test)

# %% [markdown]
# ** Create a confusion matrix and classification report using these predictions and y_test **

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test,predictions))
# Out:
# [[159  69]
#  [ 22 976]]
#
#
#              precision    recall  f1-score   support
#
#           1       0.88      0.70      0.78       228
#           5       0.93      0.98      0.96       998
#
# avg / total       0.92      0.93      0.92      1226

# %% [markdown]
# **Great! Let's see what happens if we try to include TF-IDF to this process using a pipeline.**

# %% [markdown]
# # Using Text Processing
#
# ** Import TfidfTransformer from sklearn. **

# %%
from sklearn.feature_extraction.text import  TfidfTransformer

# %% [markdown]
# ** Import Pipeline from sklearn. **

# %%
from sklearn.pipeline import Pipeline

# %% [markdown]
# ** Now create a pipeline with the following steps:CountVectorizer(), TfidfTransformer(),MultinomialNB()**

# %%
pipeline = Pipeline([
    ('bow', CountVectorizer()),  # strings to token integer counts
    ('tfidf', TfidfTransformer()),  # integer counts to weighted TF-IDF scores
    ('classifier', MultinomialNB()),  # train on TF-IDF vectors w/ Naive Bayes classifier
])

# %% [markdown]
# ## Using the Pipeline
#
# **Time to use the pipeline! Remember this pipeline has all your pre-process steps in it already, meaning we'll need to re-split the original data (Remember that we overwrote X as the CountVectorized version. What we need is just the text**

# %% [markdown]
# ### Train Test Split
#
# **Redo the train test split on the yelp_class object.**

# %%
X = yelp_class['text']
y = yelp_class['stars']
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3,random_state=101)

# %% [markdown]
# **Now fit the pipeline to the training data. Remember you can't use the same training data as last time because that data has already been vectorized. We need to pass in just the text and labels**

# %%
# May take some time
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('bow', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_...f=False, use_idf=True)), ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %% [markdown]
# ### Predictions and Evaluation
#
# ** Now use the pipeline to predict from the X_test and create a classification report and confusion matrix. You should notice strange results.**

# %%
predictions = pipeline.predict(X_test)

# %%
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[  0 228]
#  [  0 998]]
#              precision    recall  f1-score   support
#
#           1       0.00      0.00      0.00       228
#           5       0.81      1.00      0.90       998
#
# avg / total       0.66      0.81      0.73      1226
# /Users/marci/anaconda/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# Looks like Tf-Idf actually made things worse! That is it for this project. But there is still a lot more you can play with:
#
# **Some other things to try....**
# Try going back and playing around with the pipeline steps and seeing if creating a custom analyzer like we did in the lecture helps (note: it probably won't). Or recreate the pipeline with just the CountVectorizer() and NaiveBayes. Does changing the ML model at the end to another classifier help at all?

# %% [markdown]
# # Great Job!
